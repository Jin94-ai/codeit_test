# %% [markdown]
# # 김보윤 - Full Stack Developer
#
# ---
#
# ## About Me
#
# 프론트엔드부터 백엔드까지 전 영역을 다루는 풀스택 개발자입니다.
# Python 기반 웹 개발과 사용자 경험 개선에 열정이 있습니다.
#
# ## Skills
#
# ```
# Backend  → Python, Flask, Django, FastAPI
# Frontend → HTML/CSS, JavaScript, React
# Database → MySQL, MongoDB, SQLite
# DevOps   → Git, Docker, CI/CD
# ```
#
# ## Contact
#
# - Email: boyoon.kim@example.com
# - GitHub: [@kim-boyoon](https://github.com/kim-boyoon)
# - Portfolio: [boyoon.dev](https://boyoon.dev)

# %% [markdown]
# ---
#
# ## Flask Web App Example

# %%
from flask import Flask, jsonify, request
from datetime import datetime

app = Flask(__name__)

# In-memory database
tasks = [
    {"id": 1, "title": "GitHub 협업 연습", "completed": False},
    {"id": 2, "title": "Python 프로젝트 완성", "completed": True}
]

@app.route('/api/tasks', methods=['GET'])
def get_tasks():
    return jsonify(tasks)

@app.route('/api/tasks', methods=['POST'])
def create_task():
    new_task = {
        'id': len(tasks) + 1,
        'title': request.json.get('title'),
        'completed': False
    }
    tasks.append(new_task)
    return jsonify(new_task), 201

# Example usage
print("Flask API 예제")
print(f"등록된 태스크: {len(tasks)}개")
for task in tasks:
    status = "완료" if task['completed'] else "진행중"
    print(f"  - {task['title']}: {status}")

# %% [markdown]
# ---
#
# ## Projects Timeline
#
# ### 2024
#
# #### 블로그 플랫폼
# - **Tech Stack**: Flask + React + PostgreSQL
# - **Features**: 마크다운 에디터, 댓글 시스템, 태그 검색
# - **Role**: Full Stack Development
#
# #### 실시간 협업 도구
# - **Tech Stack**: Django + WebSocket + Redis
# - **Features**: 실시간 문서 편집, 채팅, 알림
# - **Role**: Backend & Real-time Communication
#
# ### 2023
#
# #### E-commerce 사이트
# - **Tech Stack**: Django + Vue.js + MySQL
# - **Features**: 장바구니, 결제, 재고 관리
# - **Role**: Full Stack Development
#
# #### RESTful API 서비스
# - **Tech Stack**: FastAPI + MongoDB
# - **Features**: JWT 인증, API 문서화, 속도 제한
# - **Role**: Backend API Design

# %% [markdown]
# ---
#
# ## Experience
#
# **주니어 개발자** (2023 - 현재)
#
# - Python 기반 웹 애플리케이션 개발 및 유지보수
# - RESTful API 설계 및 데이터베이스 최적화
# - 프론트엔드 UI/UX 개선 및 반응형 디자인 구현
# - 코드 리뷰 및 팀 협업 프로세스 개선
